# %% [markdown]
# # Import packages

# %%
import numpy as np
import pandas as pd
import re
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

import os
import glob
import shutil

import sys

import CFPy as cfpy
import flopy as flopy
import flopy.utils.binaryfile as bf
import pykasso as pk

# %% [markdown]
# # Define functions

# %% [markdown]
# ## Helpers

# %%
def position_to_index(x, y):
    """
    Get the modflow (!) based index for a given geo position
    
    Keyword Arguments
    x -- x position, m
    y -- y position, m
    
    Return
    column index, row index
    """
    
    col_idx = np.floor(x / delr) + 1
    row_idx = n_rows - np.floor(y / delc)
    
    return col_idx, row_idx

def store_results(number):
    """
    Create a directory and put the current results there
    
    Keyword Arguments
    number -- identifier of the current iteration, float or int
    
    Return
    -
    """
    
    # define directory where to store the results
    target_dir = os.path.join(path, f"EX05_run_{number}")
    
    # make sure the directory does not exist
    if os.path.exists(target_dir):
        raise Exception(f"Directory {target_dir} exists already! Unable to write results")
        
    # create directory
    os.makedirs(target_dir)
    
    # get alle files that will be moved
    files_to_move = glob.glob("NODE*") + glob.glob("TUBE*") \
                    + [f"{modelname}.list", f"{modelname}.hds", f"{modelname}.cbc"] \
                    + [f"network_{number}.png"] \
                    + glob.glob("*.nbr") + glob.glob("*.coc") + glob.glob("*.cfp") + glob.glob("*.crch")
    
    # move files to directory
    for f in files_to_move:
        source = os.path.join(path, f)
        destination = os.path.join(target_dir, f)
        shutil.move(source, destination)

def clean_results():
    """
    Remove all run-dictionaries
    
    Keyword Arguments
    -
    
    Return
    -
    """    
    run_dirs = glob.glob(os.path.join(path, "EX05_run_*"))    
    for rd in run_dirs:
        shutil.rmtree(rd)

# %% [markdown]
# ## Modflow

# %%
def init_dis_module():
    """
    Initialise discretization Module
    
    Keyword Arguments
    -
    
    Return
    ModflowDis object
    """

    # Create dis object
    dis = flopy.modflow.ModflowDis(mf, n_lays, n_rows, n_cols, n_pers, delr, delc, 
                                   top=lay_elevs[0], botm=lay_elevs[1],
                                   perlen=perlen, nstp=n_stps, steady=steady,
                                   itmuni=time_unit, lenuni=2)

    return dis

def init_bas_module():
    """
    Initialise BAS6 Module
    
    Keyword Arguments
    -
    
    Return
    ModflowBas object
    """

    # if ibound < 0: constant head, if = 0: inactive, if > 0: active.
    # create arrays to indicate active cells (ibound) and starting heads (H_init)

    # integer array of dim (z,y,x), makes all cells active 
    ibound = np.ones((n_lays, n_rows, n_cols), dtype=np.int32)

    # replace leftmost column with -1 to indicate constant head 
    ibound[:,:,0] = -1

    # initialize starting head array
    H_init_array = np.ones((n_lays, n_rows, n_cols), dtype=np.float32)
    # assign starting head values to all cells
    H_init_array[:,:,:] = H_init
    # assign constant head value to leftmost column
    H_init_array[:,:,0] = chb_left

    bas = flopy.modflow.ModflowBas(mf, ibound=ibound, strt=H_init)
    
    return bas

def init_lpf_module():
    """
    Initialise LPF Module
    
    Keyword Arguments
    -
    
    Return
    ModflowLpf object
    """
    
    # Only one of either the BCF, LPF, or HUF2 packages should be used to control flow between cells
    # Can also in this package set confined/unconfined (defaults to confined), cell-by-cell Ks as an array, 
    # storage, specific yield, etc.
    # defaults to confined

    #unit number to save outputs to
    ipakcb = 50
    #value assigned to dry cells
    hdry = 999.
    #0=confined, >0 = unconfined/convertible
    laytyp = 1
    #method of calculating interblock tranmissivity, 0=harmonic mean (default)
    layavg = 0
    #horizontal anisotropy (ratio of Ky (along cols) to Kx (along rows)
    chani = 1
    #indicates vka = Kz
    layvka = 0
    #wetting, 0=inactive, 1=active
    laywet = 0

    lpf = flopy.modflow.ModflowLpf(mf, laytyp=laytyp, chani=chani, layvka=layvka, laywet=laywet, 
                ipakcb=ipakcb, hdry=hdry, hk=hk, hani=chani, vka=vka, wetdry=laywet)
    
    return lpf

def init_oc_module():
    """
    Initialise OC Module
    
    Keyword Arguments
    -
    
    Return
    ModflowOc object
    """
    
    # create dictionary
    per_dict = {(0,0):['print head', 'save head', 'save budget']}

    # create output control file using dictionary
    oc = flopy.modflow.ModflowOc(mf, stress_period_data=per_dict)
    
    return oc

def init_pcg_module():
    """
    Initialise PCG Module
    
    Keyword Arguments
    -
    
    Return
    ModflowPcg object
    """

    #max number of outer iterations
    mxiter = 2000
    #number of inner iterations
    iter1 = 2000
    #flag for matrix conditioning method, 1=modified incomplete cholesky
    npcond = 1
    #flag for active cell surrounded by dry cells. 0=converts to dry, not0=converts only if hcof=0
    ihcofadd = 9999
    #relaxation parameter with npcond=1
    relax = mfrelax
    #estimate of upper bound
    nbpol = 2
    #printout interval
    iprpcg = 5
    #print flag, 5=?
    mutpcg = 0
    #damping factor
    damppcg = 0.99

    pcg = flopy.modflow.ModflowPcg(mf, mxiter=mxiter, iter1=iter1, npcond=npcond, hclose=mftol, rclose=mftol, 
                                   relax=relax, nbpol=nbpol, iprpcg=iprpcg, mutpcg=mutpcg, damp=damppcg,
                                   ihcofadd=ihcofadd)
    return pcg

def init_rch_module():
    """
    Initialise RCH Module
    
    Keyword Arguments
    -
    
    Return
    ModflowRch object
    """

    # flag, 1=rech only applied to top layer
    nrchop = 1
    # if non-zero, cell budget data will be saved
    ipakcb = 50
    
    # recharge from mm/a to m/s
    recharge_si = recharge / (365.25 * 24 * 60 * 60 * 1000)

    # dictionary of recharge fluxes for each stress period
    rech = {0:recharge_si}

    rch = flopy.modflow.mfrch.ModflowRch(mf, nrchop=nrchop, ipakcb=ipakcb, rech=rech)
    
    return rch

def write_model():
    """
    Write model
    
    Keyword Arguments
    mf -- model object
    
    Return
    -
    """
        
    mf.write_input()

def run_model():
    """
    Run model
    
    Keyword Arguments
    mf -- model object
    
    Return
    State of success
    """
        
    success, buff = mf.run_model(silent=False)
    
    return success

# %% [markdown]
# ## CFPy

# %%
def create_network():
    """
    Create the network with pyKasso and process/export it with cfpy
    
    Keyword Arguments
    yaml_file -- absolute path to settings file of pyKasso, str
    
    Return
    validator object, valid network array
    """
    
    # read in settings file
    catchment = pk.SKS(yaml_settings_file=yaml_file)
    
    # compute karst networks from the given information
    catchment.compute_karst_network()

    # generate elevation data
    # NOTE: elevation data has to have the same shape as the node network array!
    shp = np.array(catchment.karst_simulations[-1].maps['karst'][-1]).shape
    # Set elevation of all nodes
    elevs = np.ones(shp) * elev_nodes
    # validate the network from pyKasso
    validator = cfpy.preprocessing.pyKassoValidator(network=catchment, elevations=elevs)
    valid_network = validator.validate_network()
    
    # export the network
    # the exported information can directly be included in the .nbr-file as input for CFPy
    # notes on how to use the generated data with CFPy is given at the end of the notebook
    # per default, the network is exported to "CFPy_exported_network_for_NBR.txt" in the active directory
    validator.export_network()
    
    return validator, valid_network

def plot_network(valid_network, number):
    """
    Plot and save valid network array as png
    
    Keyword Arguments
    valid_network -- valid network array
    number -- identifier of the current iteration, float or int
    
    Return
    -
    """
    
    # create a figure 
    fig = plt.figure(figsize=(10, 10))
    
    # plot the array
    im = plt.imshow(valid_network)
    cb = plt.colorbar(im, shrink=0.3)
    
    # set descriptions
    plt.xlabel("Colum Index", size=14)
    plt.ylabel("Row Index", size =14)
    cb.set_label("Elevation, m", size=14)
    
    # save figure
    plt.savefig(f'network_{number}.png')

def create_nbr(validator):
    """
    Create nbr file
    
    Keyword Arguments
    validator -- validator object
    
    Return
    -
    """
    
    # generate nbr file
    validator.generate_nbr(
        path = path,
        nrows = n_rows,
        ncols = n_cols,
        nlays = n_lays,
        nplanes = 1,
        layer_elevations = lay_elevs_array
    )
    
def read_nbr():
    """
    Read in nbr data
    
    Keyword Arguments
    -
    
    Return
    nbr data, conduits elevation
    """
    
    # create nbr object
    nbr = cfpy.nbr()

    # read model layer/node and conduit layer/node elevations

    # bot_elev has shape (n_layers, n_rows, n_cols)
    # cond_elev has shape (n_conduit_layers, n_rows, n_cols)
    # function looks for an .nbr-file, if none or more than one file is found, an error is raised
    # make sure to only have one .nbr-file in the working directory
    bot_elev, cond_elev = nbr.nbr_read()

    # create nbr data
    nbr_data = nbr.nbr(bot_elev, cond_elev)
    
    return nbr_data, cond_elev

def create_pipe_data(p_num):
    """
    Create nested list of pipe data. Assuming same characteristics for all pipes
    
    Keyword Arguments
    p_num -- pipe numbers, i.e. nbr_data[5]
    
    Return
    pipe data
    """

    # diameter
    p_diameter = np.ones(len(p_num)) * diameter
    p_diameter = p_diameter.tolist()

    # tortuosity
    p_tortuosity = np.ones(len(p_num)) * tortuosity
    p_tortuosity = p_tortuosity.tolist()

    # roughness height
    p_rheight = np.ones(len(p_num)) * rheight
    p_rheight = p_rheight.tolist()

    # lower critical reynolds number
    p_lcritrey = np.ones(len(p_num)) * lcritrey
    p_lcritrey = p_lcritrey.tolist()

    # higher critical reynolds number
    p_hcritrey = np.ones(len(p_num)) * hcritrey
    p_hcritrey = p_hcritrey.tolist()

    # summarize all data in a 2D-array
    pipe_data = [p_num, p_diameter, p_tortuosity, p_rheight, p_lcritrey, p_hcritrey]
    
    return pipe_data

def create_node_data(n_num, nodes_locations):
    """
    Create nested list of node head data.
    
    Keyword Arguments
    n_num -- node numbers, i.e. nbr_data[0]
    nodes_locations -- node locations, i.e. nbr_data[2]
    
    Return
    node head data
    """

    # parametrization for all n nodes
    # if head > 0: fixed head
    # if head == -1: calculated head
    n_head = np.ones((len(n_num))) * -1
    n_head = n_head.tolist()

    # search if the spring exists in the nodes
    if idxs_spring in nodes_locations:
        # get the position of spring node inside nbr_data
        pos = nodes_locations.index(idxs_spring)
        # assign the head to spring node
        n_head[pos] = chb_spring
    else:
        raise Exception("Cannot find indices of spring in the indices of nodes!")

    node_data = [n_num, n_head]
    
    return node_data

def create_kex_data(n_num):
    """
    Create nested list of conduit wall conductivity. 
    Assuming same characteristics for all conduits.
    
    Keyword Arguments
    n_num -- node numbers, i.e. nbr_data[0]
    kex -- conduit wall conductivity, m^2/s (if sa_exchange = 0)
    
    Return
    conduit wall conductivity data
    """

    kex_data = [n_num,
                np.ones(len(n_num)) * k_exchange]
    
    return kex_data

def create_cads_data(n_num):
    """
    Create list of conduit associated storage (CADS). 
    Assuming same characteristics for all conduits.
    
    Keyword Arguments
    n_num -- node numbers, i.e. nbr_data[0]
    cad -- conduit associated storage, m
    
    Return
    CADS data
    """
    
    cads_data = np.ones((len(n_num))) * cad
    cads_data = cads_data.tolist()
    
    return cads_data

def init_cfp_module(nbr_data, cond_elev, pipe_data, node_data, kex_data, cads_data):
    """
    Initialise CFP Module
    
    Keyword Arguments
    nbr_data -- nbr data
    cond_elev -- conduit elevation
    pipe_data -- pipe data
    node_data -- node head data
    kex_data -- conduit wall conductivity data
    cads_data -- CADS data
    
    Return
    cfp object
    """

    cfp = cfpy.cfp(mode = 1,
                   nnodes = len(nbr_data[0]), 
                   npipes = len(nbr_data[5]), 
                   nlay = n_lays, 
                   nbr_data = nbr_data, 
                   geoheight = cond_elev, 
                   sa_exchange = 0, 
                   epsilon = cfptol,
                   niter = 2000, 
                   relax = cfprelax, 
                   p_nr = 0, 
                   cond_data = pipe_data, 
                   n_head = node_data, 
                   k_exchange = kex_data, 
                   ncl = 0, 
                   cl = 0, 
                   ltemp = 10,
                   condl_data = 0,
                   cads = cads_data)

    # create list of strings
    cfp = cfp.cfp()
    
    return cfp

def init_coc_module(n_num, p_num):
    """
    Initialise COC Module
    
    Keyword Arguments
    n_num -- node numbers, i.e. nbr_data[0]
    p_num -- pipe numbers, i.e. nbr_data[5]
    
    Return
    coc object
    """

    coc = cfpy.coc(nnodes = len(nbr_data[0]),
                   node_numbers = nbr_data[0],
                   n_nts = 1,
                   npipes = len(nbr_data[5]), 
                   pipe_numbers = nbr_data[5],
                   t_nts = 1)

    coc = coc.coc()
    
    return coc

def init_crch_module(n_num):
    """
    Initialise CRCH Module
    
    Keyword Arguments
    n_num -- node numbers, i.e. nbr_data[0]
    
    Return
    crch object
    """

    # p_crch is list of length (n_nodes) specifying the direct recharge fraction for each node
    # initially set p_crch to 0 for all nodes (no direct recharge)
    p_crch = np.zeros((len(n_num))).tolist()

    crch = cfpy.crch(iflag_crch = 1, 
                     nper = n_pers, 
                     node_numbers = n_num, 
                     p_crch = p_crch)

    # create list of strings
    crch = crch.crch()
    
    return crch

def cfp_write_input(coc, crch, cfp):
    """
    Write CFP input
    
    Keyword Arguments
    modelname -- model name
    coc -- coc object
    crch -- crch object
    cfp -- cfp object
    
    Return
    -
    """

    input_files = cfpy.write_input(modelname = modelname,
                                   data_strings = [coc, crch, cfp],
                                   file_extensions = ['coc', 'crch', 'cfp'])

    # write CFP input files
    input_files.write_input()
    
    return input_files

def cfp_update_nam():
    """
    Update nam file
    
    Keyword Arguments
    modelname -- model name
    
    Return
    -
    """

    nam = cfpy.update_nam(modelname = modelname,
                          mode = 1,
                          cfp_unit_num = 52,
                          crch_unit_num = 53,
                          coc_unit_num = 54)

    # update existing .nam file
    nam.update_nam()
    
    return nam

# %% [markdown]
# # Declare and assign variables

# %% [markdown]
# ## Path and Model

# %%
""" create model object """

# change active directory to model directory

# FIXME: Notation here works for Linux. Notation on Github works for windows.
# Make package system independend by using for example os.path.join everywhere
path = os.getcwd() + "/"
os.chdir(path)

# path to yaml file
yaml_file = os.path.join(path, "settings2.yaml")

# set model name
modelname = "EX05_CFPy_pyKasso_network_variants"

# using the CFPv2 here, which does support CADS
# to change, type in the correct CFP version for exe_name
path_to_exe = "C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe"

mf = flopy.modflow.Modflow(modelname, exe_name=path_to_exe)

# %% [markdown]
# ## Given variables

# %%
""" define general domain characteristics """
# NOTE: n_rows, n_cols, n_lays needs to be the same as specified in the .nbr-file!

# number of rows in the domain
n_rows = 15

# number of columns in the domain
n_cols = 35

# number of layers in the domain
n_lays = 1

# width of each cell along rows, m
delr = 50.0

# width of each cell along columns, m
delc = 50.0

# layer elevations [top, bottom], [m, m]
lay_elevs = [1000.,0.]


""" hydraulic characteristics """
# horizontal hydraulic conductivity of the porous matrix, m/s
hk = 1E-5

# vertical hydraulic conductivity, m/s
vka = hk


""" time discretization """
# time units: 1=seconds, 2=minutes, 3=hours, 4=days
time_unit = 1

# define number of stress periods
n_pers = 1

# length (number of steps) of stress periods
# this variable assumes a uniform time discretization, i.e. all stress periods
# have the same number of time steps except the first stationary time step
perlen = 1

# number of time steps in each stress period (integer array)
# e.g., [1, 50, 50, 70, 33, ...]
n_stps = [perlen]

# list with "False" everywhere except 0th element (which is "True")
#     to specify steady state ("True") or transient ("False")
#     stress periods
steady = [1]


""" boundary conditions """
# recharge to WHOLE AREA, mm/a
recharge_wholearea = 316

# defined head of leftmost column, m
chb_left = 1.0

# defined head at spring node, m
chb_spring = 1.0

# matrix starting head, m
H_init = 2.0


""" solver tolerances """
# modflow general tolerance
mftol = 1e-3

# modflow relaxation parameter
mfrelax = 0.99

# CFP general tolerance
cfptol = 1e-6

# CFP relaxation parameter
cfprelax = 0.99


""" CFP variables """
# geo position of spring, only change with settings.yaml!
x_spring = 0
y_spring = 375

# elevation of all nodes, m
elev_nodes = 1.

# pipe diameter, m
diameter = 0.2

# pipe tortuosity
tortuosity = 1.

# roughness height, m
rheight = 0.02

# lower critical reynolds number
lcritrey = 1000

# higher critical reynolds number
hcritrey = 3000

# conduit wall conductivity, m^2/s
k_exchange = 0.1

# conduit associated storage (CADS), m
cad = 0.00

# %% [markdown]
# ## Derived variables

# %%
# Get the modflow indices for spring
col_idx_spring, row_idx_spring = position_to_index(x_spring, y_spring)
idxs_spring = [int(col_idx_spring), int(row_idx_spring), 1]

# Compute total length along x
Lx = n_cols*delr
# Compute total length along y
Ly = n_rows*delc

# expand elevations to array
lay_elevs_array = [np.ones((n_rows, n_cols)) * lay_elevs[0],
                   np.ones((n_rows, n_cols)) * lay_elevs[1]]

# Scale recharge so that the total volume is the same as in Birk 2002
recharge = recharge_wholearea * (delc * delr * n_cols * n_rows) / (delc * delr * (n_cols - 1) * n_rows)

# %% [markdown]
# # Set up model

# %%
dis = init_dis_module()

bas = init_bas_module()

lpf = init_lpf_module()

oc = init_oc_module()

pcg = init_pcg_module()

rch = init_rch_module()

# %% [markdown]
# # Remove pririor results

# %%
clean_results()

# %% [markdown]
# # Run loop

# %%
for i in range(100):
    write_model()
    
    validator, valid_network = create_network()

    create_nbr(validator)
    
    nbr_data, cond_elev = read_nbr()

    pipe_data = create_pipe_data(nbr_data[5])

    node_data = create_node_data(nbr_data[0], nbr_data[2])

    kex_data = create_kex_data(nbr_data[0])

    cads_data = create_cads_data(nbr_data[0])

    cfp = init_cfp_module(nbr_data, cond_elev, pipe_data, node_data, kex_data, cads_data)

    coc = init_coc_module(nbr_data[0], nbr_data[5])

    crch = init_crch_module(nbr_data[0])

    input_files = cfp_write_input(coc, crch, cfp)

    nam = cfp_update_nam()
    
    success = run_model()
    
    if success:
        
        plot_network(valid_network, i)
        
        store_results(i)
# Out:
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:49:58
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:49:58
#  ELAPSED RUN TIME:  0.634 SECONDS
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:49:58
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:49:59
#  ELAPSED RUN TIME:  0.639 SECONDS
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:49:59
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:49:59
#  ELAPSED RUN TIME:  0.270 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:00
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:00
#  ELAPSED RUN TIME:  0.250 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:01
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:01
#  ELAPSED RUN TIME:  0.350 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:02
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:02
#  ELAPSED RUN TIME:  0.230 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:02
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:03
#  ELAPSED RUN TIME:  0.260 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:03
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:03
#  ELAPSED RUN TIME:  0.244 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:04
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:04
#  ELAPSED RUN TIME:  0.361 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:05
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:05
#  ELAPSED RUN TIME:  0.238 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:05
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:05
#  ELAPSED RUN TIME:  0.210 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:06
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:06
#  ELAPSED RUN TIME:  0.650 SECONDS
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:07
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:07
#  ELAPSED RUN TIME:  0.300 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:07
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:08
#  ELAPSED RUN TIME:  0.317 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:08
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:09
#  ELAPSED RUN TIME:  0.249 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:09
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:09
#  ELAPSED RUN TIME:  0.250 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:10
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:10
#  ELAPSED RUN TIME:  0.319 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:11
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:12
#  ELAPSED RUN TIME:  0.680 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:12
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:13
#  ELAPSED RUN TIME:  0.407 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:13
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:14
#  ELAPSED RUN TIME:  0.637 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:14
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:15
#  ELAPSED RUN TIME:  0.521 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:15
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:16
#  ELAPSED RUN TIME:  0.422 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:16
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:17
#  ELAPSED RUN TIME:  0.310 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:17
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:18
#  ELAPSED RUN TIME:  0.310 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:19
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:19
#  ELAPSED RUN TIME:  0.300 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:19
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:20
#  ELAPSED RUN TIME:  0.418 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:20
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:21
#  ELAPSED RUN TIME:  0.280 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:21
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:21
#  ELAPSED RUN TIME:  0.246 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:22
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:22
#  ELAPSED RUN TIME:  0.330 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:23
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:23
#  ELAPSED RUN TIME:  0.218 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:24
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:24
#  ELAPSED RUN TIME:  0.210 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:24
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:24
#  ELAPSED RUN TIME:  0.220 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:25
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:25
#  ELAPSED RUN TIME:  0.250 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:26
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:26
#  ELAPSED RUN TIME:  0.221 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:26
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:27
#  ELAPSED RUN TIME:  0.338 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:27
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:28
#  ELAPSED RUN TIME:  0.310 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:28
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:29
#  ELAPSED RUN TIME:  0.280 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:29
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:29
#  ELAPSED RUN TIME:  0.242 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:30
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:30
#  ELAPSED RUN TIME:  0.465 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:31
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:31
#  ELAPSED RUN TIME:  0.368 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:31
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:32
#  ELAPSED RUN TIME:  0.180 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:32
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:32
#  ELAPSED RUN TIME:  0.305 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:33
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:33
#  ELAPSED RUN TIME:  0.300 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:50:34
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:50:35
#  ELAPSED RUN TIME:  0.730 SECONDS
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# ...
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:19
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:20
#  ELAPSED RUN TIME:  0.843 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:22
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:22
#  ELAPSED RUN TIME:  0.802 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:23
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:25
#  ELAPSED RUN TIME:  1.246 SECONDS
#
#  FAILED TO MEET SOLVER CONVERGENCE CRITERIA
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:25
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:25
#  ELAPSED RUN TIME:  0.438 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:27
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:27
#  ELAPSED RUN TIME:  0.757 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:28
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:29
#  ELAPSED RUN TIME:  0.688 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:30
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:31
#  ELAPSED RUN TIME:  0.866 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:31
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:32
#  ELAPSED RUN TIME:  0.412 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:33
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:34
#  ELAPSED RUN TIME:  0.748 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:35
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:35
#  ELAPSED RUN TIME:  0.365 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:36
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:37
#  ELAPSED RUN TIME:  0.473 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:37
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:38
#  ELAPSED RUN TIME:  0.366 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:38
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:39
#  ELAPSED RUN TIME:  0.736 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:40
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:40
#  ELAPSED RUN TIME:  0.311 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION
#
# Always visually check the validated network for structural correctness!
# 			i.e., whether branches are correctly isolated or if they got connected during processing.
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# FloPy is using the following  executable to run the model: C:/Users/Rudolph/Documents/GitHub/CFPy_TUD/CFPy_Examples/cfpv2.exe
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                    Version 1.9.25 06/04/2013 CFPv2 HTM/STM/UMT-LNK/CADS
# THIS IS A RESEARCH VERSION OF CFP MODE 1 FOR TEST PURPOSES WITHOUT ANY WARRANTY REGARDING CORRECTNESS
# CONTACT: THOMAS.REIMANN@TU-DRESDEN.DE AND BSHOEMAK@USGS.GOV
#
#  Using NAME file: EX05_CFPy_pyKasso_network_variants.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/09/26 15:51:41
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  RUN END DATE AND TIME (YYYY/MM/DD HH:MM:SS): 2022/09/26 15:51:41
#  ELAPSED RUN TIME:  0.386 SECONDS
#
#   NORMAL TERMINATION OF SIMULATION

# %% [markdown]
# # Post-Processing

# %% [markdown]
# ## Read in head

# %%
# get all dictionaries with results
run_dirs = glob.glob(os.path.join(path, "EX05_run_*"))
# sort in place
run_dirs.sort()

head_list = []
budget_list = []
for rd in run_dirs:
    print(f"Directory {rd}")
    # lst file name
    lst_file = os.path.join(rd, f"{modelname}.list")
    # read lst file
    lst = flopy.utils.MfListBudget(lst_file)
    # get budget
    budget = lst.get_data(totim=1)
    
    # hds file name
    hds_file = os.path.join(rd, f"{modelname}.hds")
    # read hds file
    hds = bf.HeadFile(hds_file)
    # get head
    head = hds.get_data(totim=1)
    # add to head list
    head_list.append(head)

total_head = np.concatenate(head_list)
# Out:
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_10
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_12
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_13
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_14
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_15
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_16
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_17
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_18
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_19
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_2
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_20
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_21
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_22
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_23
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_24
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_25
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_26
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_27
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_28
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_29
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_3
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_30
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_31
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_32
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_33
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_34
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_35
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_36
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_37
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_38
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_39
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_4
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_40
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_41
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_42
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_44
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_45
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_47
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_48
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_49
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_5
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_50
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_51
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_52
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_53
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_54
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_55
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_56
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_57
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_58
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_59
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_6
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_60
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_61
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_62
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_63
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_64
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_65
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_66
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_67
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_68
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_7
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_70
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_71
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_72
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_73
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_74
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_75
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_76
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_77
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_79
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_8
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_80
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_81
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_82
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_83
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_85
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_86
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_88
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_89
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_9
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_90
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_91
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_92
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_93
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_94
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_95
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_96
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_97
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_98
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_99
#    could not retrieve totime 1 from the lst file
# Could not find specified condition.
#   kstpkper = None
#   totim = 1

# %% [markdown]
# ## Plot exemplary head

# %%
run_idx = 0 

fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(1, 1, 1, aspect="equal")
im = plt.contourf(total_head[run_idx,:,:], 
                  #levels=np.linspace(np.min(total_head[run_idx,:,:]), np.max(total_head[run_idx,:,:]), 10))
                  levels=np.arange(1, 27, 2), cmap="Blues")
cb = fig.colorbar(im, shrink=0.3)

cb.set_label("Head, m", size=17)
run_number = rd.replace(os.path.join(path, "EX05_run_"), "")
plt.title(f"Head of run {run_number}", size=17) #{np.sum(success_runs)}
plt.xlabel("Column index", size=17)
plt.ylabel("Row index", size =17)

ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
cb.ax.tick_params(labelsize=16)

plt.savefig("./Example_head.png")

# %% [markdown]
# ## Plot mean head

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(1, 1, 1, aspect="equal")
im = plt.contourf(np.mean(total_head[:,:,:], axis=0), 
                  #levels=np.linspace(np.min(total_head[run_idx,:,:]), np.max(total_head[run_idx,:,:]), 10))
                  levels=np.arange(1, 27, 2), cmap="Blues")
cb = fig.colorbar(im, shrink=0.3)

cb.set_label("Head, m", size=17)
run_number = rd.replace(os.path.join(path, "EX05_run_"), "")
plt.title(f"Mean Head", size=17) #{np.sum(success_runs)}
plt.xlabel("Column index", size=17)
plt.ylabel("Row index", size =17)

ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
cb.ax.tick_params(labelsize=16)

plt.savefig("./Mean_head.png")

# %% [markdown]
# ## Plot head standard deviation

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(1, 1, 1, aspect="equal")
im = plt.contourf(np.std(total_head[:,:,:], axis=0), 
                  #levels=np.linspace(np.min(total_head[run_idx,:,:]), np.max(total_head[run_idx,:,:]), 10))
                  levels=np.arange(0, 8, 0.5), cmap="Blues")
cb = fig.colorbar(im, shrink=0.3)

cb.set_label("Head StDev, m", size=17)
run_number = rd.replace(os.path.join(path, "EX05_run_"), "")
plt.title(f"Head Standard Deviation", size=17) #{np.sum(success_runs)}
plt.xlabel("Column index", size=17)
plt.ylabel("Row index", size =17)

ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
cb.ax.tick_params(labelsize=16)

plt.savefig("./StDev_head.png")

# %% [markdown]
# ## Read in tube data

# %%
# get all dictionaries with results
run_dirs = glob.glob(os.path.join(path, "EX05_run_*"))
# sort in place
run_dirs.sort()

tube_list = []
for rd in run_dirs:
    print(f"Directory {rd}")
    
    os.chdir(rd)
    nbr_data, cond_elev = read_nbr()
    
    if idxs_spring in nbr_data[3]:
        # get the position of conduit associated with the spring node
        pos = nbr_data[3].index(idxs_spring)
        tube_number = nbr_data[5][pos]
    else:
        raise Exception("No conduit assigned to the spring")

    
    fr = cfpy.postprocessing.FileReader(
    tube_num=[tube_number],
    path=rd
    )
    node_data, tube_data = fr.read_output(cfp_version=2)
    subdf = tube_data[0]
    subdf.index = pd.Index([rd.replace(os.path.join(path, "EX05_run_"), "")])
    tube_list.append(subdf)

os.chdir(path)
# Out:
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_10
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_12
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_13
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_14
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_15
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_16
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_17
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_18
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_19
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_2
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_20
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_21
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_22
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_23
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_24
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_25
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_26
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_27
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_28
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_29
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_3
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_30
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_31
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_32
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_33
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_34
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_35
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_36
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_37
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_38
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_39
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_4
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_40
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_41
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_42
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.02 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_44
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_45
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_47
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_48
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_49
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_5
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_50
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_51
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_52
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_53
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_54
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_55
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_56
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_57
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_58
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_59
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_6
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_60
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_61
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_62
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_63
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_64
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_65
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_66
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_67
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_68
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_7
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_70
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_71
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_72
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_73
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_74
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_75
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_76
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_77
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_79
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_8
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_80
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_81
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_82
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_83
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_85
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_86
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_88
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_89
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_9
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_90
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_91
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_92
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_93
# Elapsed time (.nbr file read): 0.01 s
# Elapsed time (write nbr data): 0.0 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_94
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_95
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_96
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_97
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_98
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.01 s
# Directory C:\Users\Rudolph\Documents\GitHub\CFPy_TUD\CFPy_Examples\EX05_run_99
# Elapsed time (.nbr file read): 0.0 s
# Elapsed time (write nbr data): 0.0 s

# %% [markdown]
# ## Plot distribution of discharge

# %%
sns.set(font_scale = 1.5)
tube_df = pd.concat(tube_list)

tube_df["FLOWRATE"] = pd.to_numeric(tube_df["FLOWRATE"])
#import seaborn as sns
g = sns.displot(data = tube_df, x = "FLOWRATE", bins=100, height=10)

g.fig.suptitle("Distribution of discharge values")

g.set_axis_labels(r'Discharge, $\frac{m^3}{s}$', 'Model counts')

g.fig.tight_layout()
